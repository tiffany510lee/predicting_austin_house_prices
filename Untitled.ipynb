# %%
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("housingData.csv")
df.head(3)
# Out:
# /Users/richardlee/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (6,18,19,20,21,22,23,24,25,34,35,36,37,38,47,48,49,50,51,52,55,56,57,58,65,92,94,95,96,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,127,128,129,130,131,137,138,139,140,142,143,151,152,153,154,161,162,163,164,165,166,174,175,177,182,183,184,185,186,187,188,189,191,198,207,211,212,213,218,219,221,222,223,224,225,226,227,228,229,230,234,314,316,318,320,322,324,326,328,330,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,357,358,359,360,361,362,363,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,387,388,389,390,391,392,393,395,397,398,399,400,401,403,405,406,407,409,411,413,414,415,417,418,419,421,422,423,425,426,427,429,431,433,434,435,436,437,439,441,443,444,445,447,449,451,453,455,457,458,459,461,463,465,467,469,471,473,475,477,479,480,481,483,485,486,563,564,565,566,57
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'address_city', 'address_state',
#        'address_streetAddress', 'address_zipcode', 'bathrooms', 'bedrooms',
#        'description', 'homeStatus',
#        ...
#        'latest_salemonth', 'latest_saleyear', 'latest_price_source',
#        'numOfAccessibilityFeatures', 'numOfAppliances', 'numPhotos',
#        'numPriceChanges', 'photo', 'imagepath', 'cleanpath'],
#       dtype='object', length=138)

# %%
# we only keep the columns with at80%+ non NAs values
thres = len(df) * 0.8
df2 = df.dropna(axis='columns', thresh=thres)
df2.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1 address_city address_state  \
# 0           0            15       Austin            TX
# 1           1            16       Austin            TX
# 2           2            17       Austin            TX
#
#     address_streetAddress  address_zipcode  bathrooms  bedrooms  \
# 0    12801 Wooded Lake Ct            78732        5.0       4.0
# 1  904 Lakewood Hills Ter            78732        5.0       5.0
# 2       13701 Montview Dr            78732        3.5       NaN
#
#                                          description     homeStatus  ...  \
# 0  Gated neighborhood in Steiner Ranch. Large isl...           SOLD  ...
# 1  904 Lakewood Hills Ter, Austin, TX 78732 is a ...  RECENTLY_SOLD  ...
# 2  Great location, easy access to 620/2222. Conve...           SOLD  ...
#
#    latest_salemonth  latest_saleyear  latest_price_source  \
# 0                 2             2018       Agent Provided
# 1                 8             2020      Broker Provided
# ...

# %%
# get rid of columns that we do not need (variable selection)
columns_to_drop = ['Unnamed: 0', 'Unnamed: 0.1', 'address_streetAddress', 'description', 'latest_price_source',
                  'photo', 'imagepath', 'cleanpath']

df3 = df2.drop(columns_to_drop, axis=1)
df3.head(3)
# Out:
#   address_city address_state  address_zipcode  bathrooms  bedrooms  \
# 0       Austin            TX            78732        5.0       4.0
# 1       Austin            TX            78732        5.0       5.0
# 2       Austin            TX            78732        3.5       NaN
#
#       homeStatus   latitude  livingArea  longitude  propertyTaxRate  ...  \
# 0           SOLD  30.354322      4060.0 -97.911278             1.98  ...
# 1  RECENTLY_SOLD  30.355553      4558.0 -97.912544             1.98  ...
# 2           SOLD  30.382227      3402.0 -97.908333             1.98  ...
#
#        zpid latest_price  latest_saledatetime latest_saledate  \
# 0  70352485     715000.0  2018-02-17 00:00:00      2018-02-17
# 1  70352465    1025000.0  2020-08-06 00:00:00      2020-08-06
# 2  83823478      59000.0  2018-03-31 00:00:00      2018-03-31
#
#   latest_salemonth  latest_saleyear numOfAccessibilityFeatures  \
# 0                2             2018                          0
# ...

# %%
columns_to_drop = ['Unnamed: 0', 'Unnamed: 0.1', 'address_neighborhood', 'address_subdivision', 'dateposted',
       'description', 'photo', 'imagepath', 'cleanpath']
data = data.drop(columns_to_drop, axis=1)
data.head(3)

# %%
data['address_city'].unique()
# Out:
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4        Steiner Ranch-Lakewood Hills
#                      ...
# 16477                             NaN
# 16478                             NaN
# 16479                             NaN
# 16480                             NaN
# 16481                             NaN
# Name: address_neighborhood, Length: 16482, dtype: object

# %%
clean = pd.read_csv("clean.csv")
clean.head(3)
# Out:
#          zpid          city         streetAddress  zipcode  \
# 0   111373431  pflugerville  14424 Lake Victor Dr    78660
# 1   120900430  pflugerville    1104 Strickling Dr    78660
# 2  2084491383  pflugerville   1408 Fort Dessau Rd    78660
#
#                                          description   latitude  longitude  \
# 0  14424 Lake Victor Dr, Pflugerville, TX 78660 i...  30.430632 -97.663078
# 1  Absolutely GORGEOUS 4 Bedroom home with 2 full...  30.432673 -97.661697
# 2  Under construction - estimated completion in A...  30.409748 -97.639771
#
#    propertyTaxRate  garageSpaces  hasAssociation  ...  numOfMiddleSchools  \
# 0             1.98             2            True  ...                   1
# 1             1.98             2            True  ...                   1
# 2             1.98             0            True  ...                   1
#
#    numOfHighSchools  avgSchoolDistance  avgSchoolRating  avgSchoolSize  \
# ...

# %%
clean.columns
len(clean.columns)
# Out:
# 47

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16482 entries, 0 to 16481
# Columns: 736 entries, Unnamed: 0 to cleanpath
# dtypes: bool(13), float64(227), int64(10), object(486)
# memory usage: 91.1+ MB

# %%
data.iloc[0]
# Out:
# Unnamed: 0                                                              0
# Unnamed: 0.1                                                           15
# address_city                                                       Austin
# address_neighborhood                                                  NaN
# address_state                                                          TX
#                                               ...
# numPhotos                                                              39
# numPriceChanges                                                         1
# photo                   https://photos.zillowstatic.com/fp/911f9a59acb...
# imagepath               /content/gdrive/MyDrive/zillow-images/70352485...
# cleanpath               70352485_911f9a59acb6fe5fd909538a685e2a0c-p_f.jpg
# Name: 0, Length: 736, dtype: object

# %%
len(data.columns) # we have 736 features
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'address_city', 'address_neighborhood',
#        'address_state', 'address_streetAddress', 'address_subdivision',
#        'address_zipcode', 'bathrooms', 'bedrooms',
#        ...
#        'latest_salemonth', 'latest_saleyear', 'latest_price_source',
#        'numOfAccessibilityFeatures', 'numOfAppliances', 'numPhotos',
#        'numPriceChanges', 'photo', 'imagepath', 'cleanpath'],
#       dtype='object', length=736)

# %%
for column in data.columns:
    print(column)
# Out:
# Unnamed: 0
# Unnamed: 0.1
# address_city
# address_neighborhood
# address_state
# address_streetAddress
# address_subdivision
# address_zipcode
# bathrooms
# bedrooms
# dateposted
# description
# homeStatus
# latitude
# livingArea
# longitude
# propertyTaxRate
# resoFactsStats_accessibilityFeatures_0
# resoFactsStats_accessibilityFeatures_1
# resoFactsStats_accessibilityFeatures_2
# resoFactsStats_accessibilityFeatures_3
# resoFactsStats_accessibilityFeatures_4
# resoFactsStats_accessibilityFeatures_5
# resoFactsStats_accessibilityFeatures_6
# resoFactsStats_accessibilityFeatures_7
# resoFactsStats_additionalParcelsDescription
# resoFactsStats_appliances_0
# resoFactsStats_appliances_1
# resoFactsStats_appliances_2
# resoFactsStats_appliances_3
# resoFactsStats_appliances_4
# resoFactsStats_appliances_5
# resoFactsStats_appliances_6
# resoFactsStats_appliances_7
# resoFactsStats_appliances_8
# resoFactsStats_appliances_9
# resoFactsStats_appliances_10
# resoFactsStats_appliances_11
# ...

# %%
# get rid of columns that we do not need (variable selection)
columns_to_drop = ['Unnamed: 0', 'Unnamed: 0.1', 'address_city', 'address_neighborhood',
       'address_state', 'address_streetAddress', 'address_subdivision',
       'address_zipcode', 'bathrooms', 'bedrooms',]
data.drop(columns_to_drop, axis=1)

# %%
# train test split
train, test = train_test_split(data, test_size=0.3)
# len(train) + len(test) == len(data)
